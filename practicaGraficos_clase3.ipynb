# %%
# Importar datos en formato csv.
import pandas as pd
data_graficos = pd.read_csv('D:\\CERTIFIED BIG DATA DEVELOPER\\2020-01-31_Python/Datos_R.csv', skiprows = 2, sep = ",")

data_graficos
# Out:
#       NUMPERIODO CLIENTE  FLG_RENO  ANTIGUEDAD  CLI_CLARO  CLI_MOVISTAR  \
# 0         201902  C01353         0           9          0             0
# 1         201805  C00951         1          11          0             0
# 2         201807  C02732         0           9          0             0
# 3         201805  C02852         1          38          0             0
# 4         201901  C00031         0           2          3             0
# ...          ...     ...       ...         ...        ...           ...
# 5651      201808  C01646         0          31          7             0
# 5652      201807  C03306         0          38          0             0
# 5653      201812  C03588         0           5          0             0
# 5654      201804  C03139         0           5          0             0
# 5655      201901  C00983         0          10          0             1
#
#       CTD_PROD_ENTEL  CTD_PROD_MERC  CTD_PROD_OTROS  DEUDA_EQ  ...  \
# ...

# %%
deuda = data_graficos['DEUDA_EQ']
trafico_whatsapp = data_graficos['U_NUMTRAFICOWHATSAPP_M12']

# %%
import pandas as pd

## CONVIERTO A SERIES
deuda_serie = pd.Series(deuda)
trafico_whatsapp_serie = pd.Series(trafico_whatsapp)

# %%
trafico_whatsapp_serie
# Out:
# 0        313.631582
# 1        693.745410
# 2        216.224543
# 3       1309.879108
# 4        384.225407
#            ...
# 5651       0.108520
# 5652     273.519741
# 5653     825.218418
# 5654     377.454617
# 5655      79.384183
# Name: U_NUMTRAFICOWHATSAPP_M12, Length: 5656, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(deuda_serie, trafico_whatsapp_serie, 'ro') #añadir, 'bo' - 'go' - 'go-' - 'rs'
plt.xlabel("trafico whatsapp")
plt.ylabel("deuda_serie")
# Out:
# Text(0, 0.5, 'deuda_serie')

# %%
# Out:
# 0        313.631582
# 1        693.745410
# 2        216.224543
# 3       1309.879108
# 4        384.225407
#            ...
# 5651       0.108520
# 5652     273.519741
# 5653     825.218418
# 5654     377.454617
# 5655      79.384183
# Name: U_NUMTRAFICOWHATSAPP_M12, Length: 5656, dtype: float64
